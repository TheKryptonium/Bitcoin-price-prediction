# %% [markdown]
# # BITCOIN PRICE PREDICTOR

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# %pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (4.25.5)
# Requirement already satisfied: websockets>=13.0 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from curl_cffi>=0.7->yfinance) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: pycparser in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: six>=1.5 in c:\users\kryptonium\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.3
# [notice] To update, run: C:\Users\KRYPTONIUM\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip

# %%
import yfinance as yf

# %%
data = yf.download("BTC", "2024-01-01", "2025-11-01", auto_adjust=True)
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open   Volume
# Ticker            BTC        BTC        BTC        BTC      BTC
# Date
# 2024-07-31  28.950001  29.650000  28.799999  29.500000   930940
# 2024-08-01  28.100000  28.799999  27.600000  28.650000  8564500
# 2024-08-02  27.799999  29.049999  27.650000  28.750000  2412560
# 2024-08-05  23.750000  24.650000  22.000000  22.049999  3141140
# 2024-08-06  25.250000  25.350000  24.150000  24.500000  1690140

# %%
data.shape
# Out:
# (316, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 316 entries, 2024-07-31 to 2025-10-31
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   (Close, BTC)   316 non-null    float64
#  1   (High, BTC)    316 non-null    float64
#  2   (Low, BTC)     316 non-null    float64
#  3   (Open, BTC)    316 non-null    float64
#  4   (Volume, BTC)  316 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 14.8 KB

# %%
data.describe()
# Out:
# Price        Close        High         Low        Open        Volume
# Ticker         BTC         BTC         BTC         BTC           BTC
# count   316.000000  316.000000  316.000000  316.000000  3.160000e+02
# mean     41.445443   42.014212   40.865677   41.455997  1.494717e+06
# std       8.664906    8.694211    8.665401    8.697528  9.552841e+05
# min      23.750000   24.650000   22.000000   22.049999  4.479000e+05
# 25%      36.475001   36.809999   35.620001   36.309999  9.231750e+05
# 50%      42.975000   43.895000   42.470001   43.184999  1.224900e+06
# 75%      48.452498   49.064750   48.052500   48.515000  1.719775e+06
# max      55.570000   55.959999   55.115002   55.330002  8.564500e+06

# %%
data.Close.plot(figsize=(10,7), color='b').set_facecolor('black')
plt.ylabel('BTC Prices')
plt.title('BTC Price Series')
plt.show()

# %%
sns.histplot(data["Close"])
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data["Open"])
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data["High"])
# Out:
# <Axes: ylabel='Count'>

# %%
X = data.drop('Close', axis=1)
y = data['Close']

X_train, X_test, y_train,y_test = train_test_split(X, y, test_size=20, random_state=0)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
# Out:
# (296, 4)
# (20, 4)
# (296, 1)

# %% [markdown]
# ### LINEAR REGRESSION

# %%
y_train
# Out:
# Ticker            BTC
# Date
# 2024-09-06  23.750000
# 2025-03-20  37.310001
# 2025-05-16  46.150002
# 2025-07-30  51.770000
# 2025-07-28  52.330002
# ...               ...
# 2025-08-01  50.049999
# 2025-05-07  42.610001
# 2025-01-17  46.430000
# 2024-10-07  28.100000
# 2025-04-08  33.990002
#
# [296 rows x 1 columns]

# %%
lr  = LinearRegression().fit(X_train, y_train)

predict = lr.predict(X_test)
print(predict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 lr  = LinearRegression().fit(X_train, y_train)
#       3 predict = lr.predict(X_test)
#       4 print(predict)
#
# NameError: name 'LinearRegression' is not defined

# %%
from sklearn.metrics import r2_score


mse = mean_squared_error(y_test, predict)
rmse = np.sqrt(mse)

print("Mean Square Error: {}".format(mse))
print("Root Mean Square Error: {}".format(rmse))
print("R2 score: {}".format(r2_score(y_test, predict)))

# %%
from sklearn.linear_model import Lasso, Ridge

la = Lasso().fit(X_train, y_train)
ri = Ridge().fit(X_train, y_train)

la_pred = la.predict(X_test)
ri_pred = ri.predict(X_test)

# %%
#Lasso regularization

mse = mean_squared_error(y_test, la_pred)
rmse = np.sqrt(mse)

print("Using Lasso Regularization")
print("\t-Mean Squared Error: {}".format(mse))
print("\t-Root Mean Square Error: {}".format(rmse))
print("\t-R2 score: {}".format(r2_score(y_test, predict)))

# %%
#Ridge regularization

mse = mean_squared_error(y_test, ri_pred)
rmse = np.sqrt(mse)

print("Using Ridge Regularization")
print("\t-Mean Squared Error: {}".format(mse))
print("\t-Root Mean Square Error: {}".format(rmse))
print("\t-R2 score: {}".format(r2_score(y_test, ri_pred)))

# %% [markdown]
# ### SUPPORT VECTOR MACHINE

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

svm = SVR()

param_grid = {'C':[0.1,1,10,100,1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel':['rbf']}

grid = GridSearchCV(SVR(), param_grid, refit=True, verbose=3)

grid.fit(X_train, y_train)

# %%
best_params = grid.best_params_

print("Best obtained score:{}, for parameters: {}".format(grid.best_score_, best_params))

# %%
svr = SVR(C=10, gamma=0.0001, kernel='rbf')
svr.fit(X_train, y_train)
svr_predict = svr.predict(X_test)

# %%
#SVM 

mse = mean_squared_error(y_test, svr_predict)
rmse = np.sqrt(mse)

print("Using SVM")
print("\t-SVM Squared Error: {}".format(mse))
print("\t-SVM Mean Square Error: {}".format(rmse))
print("\t-R2 score: {}".format(r2_score(y_test, ri_pred)))

# %%
import joblib

best_model = joblib.dump(ri, 'model.pkl') #Because ridge has the best performances
